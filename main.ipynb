# %%
"""
Plantilla de Análisis de Datos con Pandas y Seaborn
Autor: [Tu Nombre]
Fecha: [Fecha de Creación]
"""
import pandas as pd

# Importamos las funciones desde functions.py
import importlib  # Importamos importlib para recargar el módulo



try:
    import utils  # Importamos las funciones desde utils.py
    importlib.reload(utils)
except ImportError:
    print("Error: No se pudo importar 'utils.py'. Asegúrate de que el archivo está en el mismo directorio.")

# Cargar el dataset Titanic desde una fuente en línea
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/titanic_train.csv'
df = utils.load_dataframe(url) if 'utils' in globals() else pd.read_csv(url)

# Lowercase all column names with _ for spaces
# df.columns = df.columns.str.lower().str.replace(" ", "_")

# Analizar el DataFrame
if 'utils' in globals():
    utils.analyze_dataframe(df)

# Visualizar la distribución de la edad de los pasajeros
if 'utils' in globals():
    utils.visualize_distribution(df, 'Age')

# Mostrar matriz de correlación
if 'utils' in globals():
    utils.correlation_matrix(df)
# Out:
# Resumen de información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Primeras filas del DataFrame:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# ...
